# %% [markdown]
# <a href="https://colab.research.google.com/github/moushumipriya/Machine-Learning-Projects/blob/main/ANN_METHODSS'ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data.csv')

# %% [markdown]
# Activation function (non linear)- 1.tanh( usually for RNN)
# 2.Relu (classficatiion)/CNN /Hideen layer
# 3.sigmoid(binary classsification)/multi label/ RNN
# 4.softmax (multiclass classfication)

# %% [markdown]
# Loss Function:
# error finding method in a sigle data called loss function.
#
# cost function: Mean(average value) of entire data called cost value and the method we use is called cost function.

# %% [markdown]
# #for creating best value loss function is important in Back propogation.
#
#
# loss  function for
# REgression porblem:
# 1.MSE (most used /popular) (we shouldnt use that if data has outlier)
# 2.MAE (if outlier has i data then we will use this)
# 3.Hubber loss (if data has minimum outlier /30%)
#
# for CLASSIFICATION:
# 1.Binary cross entropy/log loss (ouput as binary format 0/1)
# 2.catergorical cross entropy (for catogorical data in output) [one hot encoding]
# #Sparsh categorical cross entroty( most used for 5 or more output) [lebel encoding]
#
# also auto encoder ,gan,object detection,word embedding has diffrent types of loss function.

# %% [markdown]
# #optimizer for minimize the loss:(getting out from local minima problem)
#
# #ADAM (most used)
# GOOD TO GO >

# %% [markdown]
# deep learning method:
# in medical dataset..
#
# we will discuss about every method of NEURAL network.

# %%
df.head(3)
# Out:
#    Age Gender Smoking Hx Smoking Hx Radiothreapy Thyroid Function  \
# 0   27      F      No         No              No        Euthyroid
# 1   34      F      No        Yes              No        Euthyroid
# 2   30      F      No         No              No        Euthyroid
#
#           Physical Examination Adenopathy       Pathology   Focality Risk  \
# 0   Single nodular goiter-left         No  Micropapillary  Uni-Focal  Low
# 1          Multinodular goiter         No  Micropapillary  Uni-Focal  Low
# 2  Single nodular goiter-right         No  Micropapillary  Uni-Focal  Low
#
#      T   N   M Stage       Response Recurred
# 0  T1a  N0  M0     I  Indeterminate       No
# 1  T1a  N0  M0     I      Excellent       No
# 2  T1a  N0  M0     I      Excellent       No

# %%
df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Smoking                 0
# Hx Smoking              0
# Hx Radiothreapy         0
# Thyroid Function        0
# Physical Examination    0
# Adenopathy              0
# Pathology               0
# Focality                0
# Risk                    0
# T                       0
# N                       0
# M                       0
# Stage                   0
# Response                0
# Recurred                0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Age Gender Smoking Hx Smoking Hx Radiothreapy          Thyroid Function  \
# 0     27      F      No         No              No                 Euthyroid
# 1     34      F      No        Yes              No                 Euthyroid
# 2     30      F      No         No              No                 Euthyroid
# 3     62      F      No         No              No                 Euthyroid
# 4     62      F      No         No              No                 Euthyroid
# ..   ...    ...     ...        ...             ...                       ...
# 378   72      M     Yes        Yes             Yes                 Euthyroid
# 379   81      M     Yes         No             Yes                 Euthyroid
# 380   72      M     Yes        Yes              No                 Euthyroid
# 381   61      M     Yes        Yes             Yes  Clinical Hyperthyroidism
# 382   67      M     Yes         No              No                 Euthyroid
#
# ...

# %%
#lets spilt the x and y

# %%
input_df=df.iloc[:,0:1]
output_df=df.iloc[:,-1]

#we will scale the x data using sk learn


from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
input_df=pd.DataFrame(scaler.fit_transform(input_df),columns=input_df.columns)

# %%
input_df
# Out:
#           Age
# 0   -0.917439
# 1   -0.454315
# 2   -0.718957
# 3    1.398184
# 4    1.398184
# ..        ...
# 378  2.059790
# 379  2.655236
# 380  2.059790
# 381  1.332023
# 382  1.728987
#
# [383 rows x 1 columns]

# %% [markdown]
# #Making of ANN

# %%
import tensorflow as tf
from keras.layers import Dense
from keras.models import Sequential
ann=Sequential()

# %%
input_df.shape
# Out:
# (383, 1)
# (383, 1)

# %%
#lets creat the neural network
